# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewMelekhov/ColabFiles/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 3. В строке FIO находится фамилия, имя и отчество. Записать их в три отдельные строки: lastname, firstname и patronymic.
FIO = 'Иванов Иван Иваныч'
#s = input('F I O:')

# способ 1 find и срезы:
lastname = FIO[:FIO.find(' ')]
name = FIO[FIO.find(' ') + 1 : FIO.rfind(' ')]
patronymic = FIO[FIO.rfind(' ') + 1:]
print('Фамилия: ', lastname)
print('Имя: ', name)
print('Отчество: ', patronymic)

#способ 2 split:
lastname, firstname, patronymic = FIO.split()
print('Фамилия: ', lastname)
print('Имя: ', name)
print('Отчество: ', patronymic)

# способ 3 циклы:
i = 0
lastname = ''
while i < len(s) and s[i] != ' ':
    lastname = lastname + s[i]
    i = i + 1
firstname = ''
i = i + 1
while i < len(s) and s[i] != ' ':
    firstname = firstname + s[i]
    i = i + 1
patronymic = s[i+1:]
print('Фамилия: ', lastname)
print('Имя: ', name)
print('Отчество: ', patronymic)

# %%
# Дан список целых чисел (поиски).
L = [-7, 4, 5, -8, 0, 10, -22]

# 1) Определить, есть ли в списке элемент равный 5.

# Cпособ 0:
print('Есть ли в списке элемент равный 5: ', 5 in L)

# Cпособ 1:
bEqual_5 = False
for i in range(len(L)):
    if L[i] == 5:
        bEqual_5 = True
        break
print('Есть ли в списке элемент равный 5: ', bEqual_5)

# Cпособ 2:
bEqual_5 = False
i = 0
while  i < len(L) and not bEqual_5:
    if L[i] == 5:
        bEqual_5 = True
    i = i + 1
print('Есть ли в списке элемент равный 5: ', bEqual_5)


L = [5, 5, 5, -5, 5, 5, 5]
# 2) Определить, все ли в списке элементы равны 5.
b5 = True
i = 0
while i < len(L) and b5:
    if L[i] != 5:
        b5 = False
    i += 1
print('Все ли в списке элементы равны 5:', b5)


# 3) Определить, сколько в списке элементов равных 5.
L = [50, 5, -5, 10, 5]
i = 0
c = 0 # количество
while i < len(L):
    if L[i] == 5:
       c += 1
    i += 1
print('Количество:', c)

count = 0 # количество
for i in range(len(L)):
    if L[i] == 5:
       count += 1
print('Количество:', count)

# 4) Определить, номер элемента равного 5.
# Если такого элемента нет, выдать сообщение об этом.
L = [5, 0, 0, 0, 0, 5, 0, 10]
c = -1  # берем не существующий в списке номер числа 5
for i in range(len(L)):
    if L[i] == 5:
        c = i
        break
if c == -1: print('5 в списке нет')
else: print('Номер первой 5:', c)

L = [10, 0, 5]
i = 0; n = len(L)
while (i < n) and (L[i] != 5): i += 1
if i == n: print('5 нет в списке')
else: print('номер', i)

# 5) Найти в списке, элемент равный 5 и поменять его с первым элементом.
L = [1,0,0,0,0,0,5,10]
c = L[0]
for i in range(len(L)):
    if L[i] == 5:
        L[0] = L[i]
        L[i] = c
        break
print(L)

L = [1,0,0,0,0,0,5,10]
for i in range(len(L)):
    if L[i] == 5:
        L[0], L[i] = L[i], L[0]
        break
print(L)

L = [1,0,0,0,0,0,5,10]
c = -1  # берем не существующий в списке номер числа 5
for i in range(len(L)):
    if L[i] == 5:
        c = i
        break
if c >= 0:  L[0], L[i] = L[i], L[0]
print(L)

# %%
# Дана матрица (выбор элементов из матрицы).
A = [[1, 2, 3], [4, -5, 6], [7, 88, -99], [100, -11, 12]]

print('Размеры матрицы:', len(A), len(A[0]))

# 1) Вывести на экран элементы первой строки.
for j in range(len(A[0])):
    print(A[0][j], end = ', ')
print()

# 2) Вывести на экран элементы i-ой строки.
i = int(input('Введите нужную строку: '))
for j in range(len(A[i])):
    print(A[i][j], end = ', ')
print()

# 3) Вывести на экран элементы первого столбца.
for i in range(len(A)):
    print(A[i][0], end = ', ')
print()

# 4) Вывести на экран элементы j-го столбца.
j = int(input('Введите номер нужного столбца: '))
for i in range(len(A)):
    print(A[i][j], end = ', ')


A = [[1,  2,  3],
     [4, -5,  6],
     [7, 88, -99]]
# 5) Вывести на экран элементы главной диагонали.
for i in range(len(A)):
   for j in range(len(A[i])):
      if i == j:
          print(A[i][j], end = ' ')
print()
for i in range(len(A)):
    print(A[i][i], end = ' ')
print()

# 6) Вывести на экран элементы побочной диагонали.

# 7) Вывести на экран элементы главной диагонали в обратном порядке.
